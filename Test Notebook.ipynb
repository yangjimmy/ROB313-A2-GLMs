# %%
from data_utils import load_dataset
import numpy as np
import math
import sys
import time
import matplotlib.pyplot as plt

# %%
xML_train, xML_valid, xML_test, yML_train, yML_valid, yML_test = load_dataset('mauna_loa')
xRB_train, xRB_valid, xRB_test, yRB_train, yRB_valid, yRB_test = load_dataset('rosenbrock', n_train=5000, d=2) #x is pairs of inputs, y is single value
xIR_train, xIR_valid, xIR_test, yIR_train, yIR_valid, yIR_test = load_dataset('iris') # x is 4 dimensional

# %%
plt.plot(xML_train,yML_train)

# %%
x = np.float32(1.0)
y = np.Inf
print(x<y)
# Out:
# True

# %%
# Creating a set using string 
test_set = set("geEks") 
  
# Iterating using for loop 
for val in test_set: 
    print(val) 
print("--")
test_set.remove("g")
for val in test_set: 
    print(val)
# Out:
# e
# k
# E
# g
# s
# --
# e
# k
# E
# s
